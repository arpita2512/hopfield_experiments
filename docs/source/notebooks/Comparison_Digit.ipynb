# %% [markdown]
# # Sync HN vs Async HN vs SOM
# **For Individual Digits**

# %%
# imports

import matplotlib.pyplot as plt
import pickle
import gc
import seaborn as sns
import pandas as pd
import numpy as np
import mplcyberpunk

plt.style.use("cyberpunk")

seed = 42
np.random.seed(seed)

# %%
# setting font size for graphs

SIZE = 14

plt.rc('font', size=SIZE)
plt.rc('axes', titlesize=SIZE)  
plt.rc('axes', labelsize=SIZE)  
plt.rc('xtick', labelsize=SIZE)    
plt.rc('ytick', labelsize=SIZE)  
plt.rc('legend', fontsize=SIZE) 
plt.rc('figure', titlesize=SIZE)

# set color cycle

plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab10.colors)

# %%
# metrics for sync hn

with open("mse_sync.pkl", 'rb') as f:
    mse_sync = pickle.load(f)
with open("psnr_sync.pkl", 'rb') as f:
    psnr_sync = pickle.load(f)
with open("ssim_sync.pkl", 'rb') as f:
    ssim_sync = pickle.load(f)

# metrics for som

with open("mse_som.pkl", 'rb') as f:
    mse_som = pickle.load(f)
with open("psnr_som.pkl", 'rb') as f:
    psnr_som = pickle.load(f)
with open("ssim_som.pkl", 'rb') as f:
    ssim_som = pickle.load(f)

# %%
# metrics for 0

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[0], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[0], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 0")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 1

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[1], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[1], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 1")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 2

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[2], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[2], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 2")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 3

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[3], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[3], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 3")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 4

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[4], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[4], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 4")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 5

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[5], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[5], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 5")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 6

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[6], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[6], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 6")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 7

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[7], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[7], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 7")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 8

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[8], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[8], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 8")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
# metrics for 9

plt.figure(figsize=(10, 5))

plt.plot(np.arange(0, 1.1, 0.1), mse_sync[9], marker='o')
plt.plot(np.arange(0, 1.1, 0.1), mse_som[9], marker='o')
plt.xlabel("Corruption Level")
plt.ylabel("Average MSE")
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title("Average MSE for Digit 9")
mplcyberpunk.make_lines_glow()
plt.legend(['Sync HN', 'SOM'])

# %%
gc.collect()
# Out:
# 0
